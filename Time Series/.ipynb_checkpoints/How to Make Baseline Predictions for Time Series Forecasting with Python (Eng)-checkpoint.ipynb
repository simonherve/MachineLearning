# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Persistence Algorithm (the "naive" forecast)

# %% [markdown]
# ## Shampoo Sales Dataset

# %%
def parser(x):
    
    return pd.datetime.strptime("190"+x, "%Y-%m")

# %%
series = pd.read_csv("./data/shampoo-sales.csv", header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
series.plot()
plt.show()
# Out:
# <ipython-input-3-1be0bd033fc0>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime("190"+x, "%Y-%m")

# %% [markdown]
# ## Persistence algorithm
# ### Step 1: Define the Supervised Learning Problem

# %%
values = pd.DataFrame(series.values)
dataframe = pd.concat([values.shift(1), values], axis=1)
dataframe.columns = ["t-1", "t+1"]
print(dataframe.head(5))
# Out:
#      t-1    t+1
# 0    NaN  266.0
# 1  266.0  145.9
# 2  145.9  183.1
# 3  183.1  119.3
# 4  119.3  180.3

# %% [markdown]
# ### Step 2: Train and Test Sets

# %%
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# %% [markdown]
# ### Step 3: Persistence Algorithm

# %%
# persistence model
def model_persistence(x):
    return x

# %% [markdown]
# ### Step 4: Make and Evaluate Forecast

# %%
from sklearn.metrics import mean_squared_error

# %%
# walk-forward validation
predictions = list()
for x in test_X:
    yhat = model_persistence(x)
    predictions.append(yhat)
test_score = mean_squared_error(test_y, predictions)
print("Test MSE: %.3f" % test_score)
# Out:
# Test MSE: 17730.518

# %%
plt.plot(train_y)
plt.plot([None for i in train_y] + [x for x in test_y])
plt.plot([None for i in train_y] + [x for x in predictions])
plt.show()
